# %%
# external
import numpy as np
import healpy as hp
import matplotlib.pyplot as plt
# modules from curvedsky/wrap/
import basic
import curvedsky as cs
import constant as c
import cmb

# %% [markdown]
# Set parameters

# %%
nside = 1024  # Nside of Healpix map
npix  = 12*nside**2  # Numer of pixels of Healpix map
lmax  = 2*nside # Maximum multipole of harmonic coefficients to be computed

# %%
# ucl is an array of shape [0:5,0:rlmax+1] and ucl[0,:] = TT, ucl[1,:] = EE, ucl[2,:] = TE, lcl[3,:] = phiphi, lcl[4,:] = Tphi
ucl = cmb.read_camb_cls('../data/unlensedcls.dat',ftype='scal',output='array')[:,:lmax+1]

# %% [markdown]
# Generate random gaussian fields

# %%
Talm = cs.utils.gauss1alm(lmax,ucl[0,:])
Tmap = cs.utils.hp_alm2map(nside,lmax,lmax,Talm)

# %%
palm = cs.utils.gauss1alm(lmax,ucl[3,:])
pmap = cs.utils.hp_alm2map(nside,lmax,lmax,palm)

# %%
hp.mollview(Tmap)
# Out:
# /global/homes/t/toshiyan/.conda/envs/loc/lib/python3.7/site-packages/healpy/projaxes.py:920: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("viridis"))
#   newcm.set_over(newcm(1.0))
# /global/homes/t/toshiyan/.conda/envs/loc/lib/python3.7/site-packages/healpy/projaxes.py:921: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("viridis"))
#   newcm.set_under(bgcolor)
# /global/homes/t/toshiyan/.conda/envs/loc/lib/python3.7/site-packages/healpy/projaxes.py:922: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("viridis"))
#   newcm.set_bad(badcolor)
# /global/homes/t/toshiyan/.conda/envs/loc/lib/python3.7/site-packages/healpy/projaxes.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   **kwds

# %%
hp.mollview(Tmap*pmap)
