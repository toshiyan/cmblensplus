# %% [markdown]
# #### A quick demonstration of imaginary lensing reconstruction in fullsky

# %%
import numpy as np, plottools as pl, healpy as hp, binning as bn, cmb
from cmblensplus import basic, curvedsky as cs
from matplotlib.pyplot import *

# %%
def sim(lmax,rlmin,rlmax,lcl,Ag,Ac,nl):
    # gaussian alms are generated, and the reconstructed cls are equal to the normalization
    Talm, Ealm, Balm = cs.utils.gaussTEB(lcl[0,:],lcl[1,:],lcl[2,:],lcl[3,:])
    # add noise and filtering (temp)
    Talm += cs.utils.gauss1alm(nl[0,:])
    Ealm += cs.utils.gauss1alm(nl[1,:])
    Balm += cs.utils.gauss1alm(nl[2,:])
    # simple diagonal c-inverse
    Fl = np.zeros((3,lmax+1,lmax+1))
    for l in range(rlmin,rlmax):
        Fl[:,l,0:l+1] = 1./ocl[:3,l,None]
    Talm *= Fl[0,:,:]
    Ealm *= Fl[1,:,:]
    Balm *= Fl[2,:,:]
    # compute unnormalized estiamtors
    glm, clm = {}, {}
    glm['TE'], clm['TE'] = cs.rec_ilens.qte(lmax,rlmin,rlmax,lcl[3,:],Talm,Ealm)
    glm['TB'], clm['TB'] = cs.rec_ilens.qtb(lmax,rlmin,rlmax,lcl[3,:],Talm,Balm)
    glm['EE'], clm['EE'] = cs.rec_ilens.qee(lmax,rlmin,rlmax,lcl[1,:],Ealm,Ealm)
    glm['EB'], clm['EB'] = cs.rec_ilens.qeb(lmax,rlmin,rlmax,lcl[1,:],Ealm,Balm)
    glm['BB'], clm['BB'] = cs.rec_ilens.qbb(lmax,rlmin,rlmax,lcl[1,:],Balm,Balm)
    # compute auto and cross spectra
    gl, cl = {}, {}
    for qest in ['TE','TB','EE','EB','BB']:
        gl[qest] = cs.utils.alm2cl(Ag[qest][:,None]*glm[qest])
        cl[qest] = cs.utils.alm2cl(Ac[qest][:,None]*clm[qest])
    return gl['TE'], gl['TB'], gl['EE'], gl['EB'], gl['BB'], cl['TE'], cl['TB'], cl['EE'], cl['EB'], cl['BB']

# %%
# define parameters
Tcmb  = 2.726e6    # CMB temperature
lmax  = 2000       # maximum multipole of output normalization
rlmin, rlmax = 100, lmax  # reconstruction multipole range
sig   = 10.
ac2rad = np.pi/180./60.
L = np.linspace(0,lmax,lmax+1)
# for sim
simn = 1

# %%
quad = ['TE','TB','EE','EB','BB']
color = ['c','m','g','b','y']

# %% [markdown]
# #### Load unlensed and lensed Cls

# %%
lcl = cmb.read_camb_cls('../data/lensedcls.dat',ftype='lens',output='array')[:,:lmax+1]
nl  = np.zeros((4,lmax+1))
nl[0,:] = (sig*ac2rad/Tcmb)**2
nl[1,:] = 2*nl[0,:]
nl[2,:] = 2*nl[0,:]
ocl = lcl + nl

# %% [markdown]
# #### Calculate normalizations

# %%
Ag, Ac = {}, {}
Ag['TE'], Ac['TE'] = cs.norm_imag.qte('lens',rlmax,rlmin,rlmax,lcl[3,:],ocl[0,:],ocl[1,:])
Ag['TB'], Ac['TB'] = cs.norm_imag.qtb('lens',rlmax,rlmin,rlmax,lcl[3,:],ocl[0,:],ocl[2,:])
Ag['EE'], Ac['EE'] = cs.norm_imag.qee('lens',rlmax,rlmin,rlmax,lcl[1,:],ocl[1,:])
Ag['EB'], Ac['EB'] = cs.norm_imag.qeb('lens',rlmax,rlmin,rlmax,lcl[1,:],ocl[1,:],ocl[2,:])
Ag['BB'], Ac['BB'] = cs.norm_imag.qbb('lens',rlmax,rlmin,rlmax,lcl[1,:],ocl[2,:])
# Out:
#  norm qTE
#  norm qTB
#  norm qEE
#  norm qEB
#  norm qBB

# %% [markdown]
# #### Running simulation

# %%
cl = np.zeros((simn,10,lmax+1))
for i in range(simn):
    print(i)
    cl[i,:,:] = sim(lmax,rlmin,rlmax,lcl,Ag,Ac,nl)
# Out:
# 0

# %%
mb = bn.multipole_binning(20,lmax=lmax)
cls = bn.binning(cl,mb)
mgl = np.mean(cls,axis=0)
vgl = np.std(cls,axis=0)

# %%
cli = np.mean(cl,axis=0)

# %%
s = (L*(L+1))**2/2/np.pi
pl.plot_1dstyle(fsize=[10,6],xmin=1,xmax=2048,xlog=True,ylog=True)
for qi, (q,c) in enumerate(zip(quad,color)):
#for qi, q in enumerate(['EB']):
    plot(s*Ag[q],label=q,color=c,ls='--')
    plot(s*cli[qi],color=c,ls='-')
#plot(cl[q],label=q)
    #errorbar(mb.bc-5,mgl[qi,:],yerr=vgl[qi,:],fmt='o',label=q)
axhline(0,color='k',ls='--')
legend()
